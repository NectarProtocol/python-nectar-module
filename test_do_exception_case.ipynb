# %%
from nectarpy import Nectar

# %%
##Exception:

# %%
#### API_SECRET address has no balance

# %%
API_SECRET = "0x68e430fe3f72e0fec9a64d60a996ddfcc4f03f3dae653cfe1b77fcfd7f6b9127"

# %%
nectar = Nectar(API_SECRET)
# Out:
# network mode: localhost
# self.hex_pubkey
# 0455c4b2faf45142a792d1fa878dbe06137af4fae539c6a99bc9cf96c00bb14b877afec0163ec3bc0736cc9ad87b548edbd4bcf55b67467704aa9bb88b6ecb9d37
# self.hex_pubkey
# api account address: 0x9A0bc49eB68AfBAE19b46109695b2018bd7e5da7

# %%
### Add all columns

# %%
policy_id = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x0000000000000000000000000000000000000000'],
    allowed_columns=["*"],
    valid_days=1000,
    usd_price=0.0123,
)

# %%
policy_id

# %%
TEE_DATA_URL = "tls://<ip-address>:5229"

# %%
bucket_id = nectar.add_bucket(
    policy_ids=[policy_id],
    data_format="std1",
    node_address=TEE_DATA_URL,
)

# %%
bucket_id
