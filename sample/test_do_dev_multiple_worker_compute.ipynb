# %%
import os
import sys
from nectarpy import Nectar

# %%
API_SECRET = "0x0f5ac39f6cde9115133c69d30781772ab49984a790c6c1a3392b589c2e17a6da"

# %%
nectar = Nectar(API_SECRET,'localhost')

# %%
policy_id_1 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x7Fdbfd03a9e3a2d1761CAEd5eb18Ea2aa905564d'],
    allowed_columns=["*"],
    valid_days=1000,
    usd_price=0.0123,
)

# %%
policy_id_2 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x7Fdbfd03a9e3a2d1761CAEd5eb18Ea2aa905564d'],
    allowed_columns=["*"],
    valid_days=1000,
    usd_price=0.0123,
)

# %%
### Add specific columns

# %%
policy_id_1

# %%
policy_id_2

# %%
TEE_DATA_URL_1 = "tls://172.21.0.4:5229" # Example: "tls://192.168.0.12:5229"

# %%
TEE_DATA_URL_2 = "tls://172.27.0.4:5229" # Example: "tls://192.168.0.12:5229"

# %%
bucket_id_1 = nectar.add_bucket(
    policy_ids=[policy_id_1],
    data_format="std1",
    use_allowlists=[True],
    node_address=TEE_DATA_URL_1,
)

# %%
bucket_id_2 = nectar.add_bucket(
    policy_ids=[policy_id_2],
    data_format="std1",
    use_allowlists=[True],
    node_address=TEE_DATA_URL_2,
)

# %%
bucket_id_1

# %%
bucket_id_2

# %%
#de = nectar.deactivate_policy(policy_id_2)
