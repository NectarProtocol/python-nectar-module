# %%
import os
import sys
from nectarpy import NectarClient

# %%
API_SECRET = "0x08ae0c3470042b16e4ef9fe80f0552ff591ec4022eff24d67bb117be4c8b79ca"

# %%
nectar_client = NectarClient(API_SECRET,'localhost')

# %%
def count_func():
    import pandas as pd
    df = pd.read_csv("/app/data/worker-data.csv")
    return {"count": len(df)}

# %%
#Single data node

# %%
result = nectar_client.byoc_query(
    main_func = count_func, 
    bucket_ids=[82907351435983860892388544000730676991410427895802844146331593263117007585780],
    policy_indexes=[0]
)
