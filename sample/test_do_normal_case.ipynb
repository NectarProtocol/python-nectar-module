# %%
import os
import sys
# Thêm đường dẫn cha chứa nectarpy vào sys.path
project_root = os.path.abspath("../")  # từ notebooks lên 1 cấp -> /home/hoanguyen/projects/tamarin
sys.path.insert(0, project_root)
from nectarpy import Nectar

# %%
API_SECRET = "0x6bc048a309b373784f820da651363bd53d24e90507edcfe44a556605c0f1bc6e"

# %%
nectar = Nectar(API_SECRET,'localhost')

# %%
### Add all columns

# %%
policy_id_1 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x0000000000000000000000000000000000000000'],
    allowed_columns=["*"],
    valid_days=1000,
    usd_price=0.0123,
)

# %%
### Add specific columns

# %%
policy_id_2 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x0000000000000000000000000000000000000000'],
    allowed_columns=["age", "height"],
    valid_days=1000,
    usd_price=0.0123,
)

# %%
policy_id_2 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['da1'],
    allowed_columns=["age", "height"],
    valid_days=1000,
    usd_price=0.0123,
)

# %%
policy_id_3 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['da2'],
    allowed_columns=['heart_rate'],
    valid_days=1000,
    usd_price=0.0123,
}

# %%
policy_id_1

# %%
policy_id_2

# %%
TEE_DATA_URL_1 = "tls://<ip-address>:5229" # Example: "tls://192.168.0.12:5229"

# %%
TEE_DATA_URL_2 = "tls://<ip-address>:5229" # Example: "tls://192.168.0.12:5229"

# %%
bucket_id_1 = nectar.add_bucket(
    policy_ids=[policy_id_1, 2],
    data_format="std1",
    node_address=TEE_DATA_URL_1,
)

# %%
bucket_id_2 = nectar.add_bucket(
    policy_ids=[policy_id_1,policy_id_3],
    data_format="std1",
    node_address=TEE_DATA_URL_1,
)

# %%
bucket_id_1

# %%
bucket_id_2

# %%
print("Bucket IDs:", bucket_id_2 = nectar.add_bucket(
.get_bucket_ids('0x2a80e7678514000b9d90999be7a2b06799533384'))
