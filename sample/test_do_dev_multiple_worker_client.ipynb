# %%
import os
import sys
from nectarpy import Nectar

# %%
API_SECRET = "0x050834a38e0142887ff082b5923b67bf29693104a068f9ee2c1c25044f13574a"

# %%
nectar = Nectar(API_SECRET,'localhost')
# Out:
# network mode: localhost
# api account address: 0x0FC68b40cb82C3EFb991A8992043d492b280792E

# %%
### Add all columns

# %%
policy_id_1 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x7Fdbfd03a9e3a2d1761CAEd5eb18Ea2aa905564d'],
    allowed_columns=["*"],
    valid_days=1000,
    usd_price=0.0123,
)
# Out:
# adding new policy...

# %%
policy_id_2 = nectar.add_policy(
    allowed_categories=["*"],
    allowed_addresses=['0x7Fdbfd03a9e3a2d1761CAEd5eb18Ea2aa905564d'],
    allowed_columns=["*"],
    valid_days=1000,
    usd_price=0.0123,
)
# Out:
# adding new policy...

# %%
### Add specific columns

# %%
policy_id_1
# Out:
# 67697234739831717332346975469236102587644642001026447966249146503908702898893

# %%
policy_id_2
# Out:
# 17598758189111035856781325978132972006254282085771662119625611331481825052778

# %%
TEE_DATA_URL_1 = "tls://172.22.0.4:5229" # Example: "tls://192.168.0.12:5229"

# %%
TEE_DATA_URL_2 = "tls://172.27.0.4:5229" # Example: "tls://192.168.0.12:5229"

# %%
bucket_id_1 = nectar.add_bucket(
    policy_ids=[policy_id_1],
    data_format="std1",
    node_address=TEE_DATA_URL_1,
)
# Out:
# adding new bucket...
# adding new bucket - done

# %%
bucket_id_2 = nectar.add_bucket(
    policy_ids=[policy_id_2],
    data_format="std1",
    node_address=TEE_DATA_URL_2,
)
# Out:
# adding new bucket...
# adding new bucket - done

# %%
bucket_id_1
# Out:
# 61967009922181838801239149599260914605694386523894612558900626834098461111511

# %%
bucket_id_2
# Out:
# 50457995461806009622957406495585309024464525219123482152376011456519935261339
