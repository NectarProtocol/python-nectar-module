# %%
from nectarpy import NectarClient

# %%
API_SECRET = "0x55bea0b5de5944ddf44350df35943bdc1d42852e35ed667de9f1874c11871ac6"

# %%
nectar_client = NectarClient(API_SECRET)
# Out:
# network mode: localhost
# api account address: 0x39Ccc3519e16ec309Fe89Eb782792faFfB1b399d

# %%
bucket_ids = nectar_client.get_bucket_ids()

# %%
bucket_ids
# Out:
# [8826029270157355607088420759187891299277021493656505304420073732098073308366,
#  79075481192464664708560817354202146468774526494399174195604105744402252077863,
#  43386918143791445074939304788706522182858914790085169483168340191100559707217,
#  9970910464413400458422346419828178663440154913802508340617610943906896499707,
#  14112804056438109768936944087092899708204865689548385915381013406204016573004,
#  31332134037247055093195195924484125522988783356001642185011099146575898344543,
#  99953579258496982533280954803297994116444114235662506145002994011512332984605,
#  10765309967899737590378205719306789936389925032221477604373471605861655938553,
#  839716366224297417215210711662127899070303045084236474171674972157756601221,
#  275038895283257734024905037224285074474964007874954721954323735754263452583,
#  65868051804810073981106063267644021201372557196137412852483278300091432248295,
#  41342637016888216648087885821710671327842184173491854857423268023160499334459,
#  41333990732631616796993216499768669639193027548491105709542323138117070980124,
#  37268497715776922827973386558224288077062859377946933695740828852094372948247,
#  107331921349279552857434074097453474807467123546987433703324035533141150569963,
#  53730356355667827857279383840500018015709316668296027847805369048397736914532,
#  20835359958190703810032690920562787879381711544417977297759715532188539954960,
#  93087692805205224702929645742455688025377480949696647512082115422505097823112]

# %%
#### Aggregate type: Linear Regression, Mean, Count, Variance, Minimum, Maximum, Sum

# %%
def linear_regression_func():
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    df = pd.read_csv("/app/data/worker-data.csv")
    df_filtered = df[df['age'] > 50]
    x_values = ["heart_rate","age"]
    y_values = 'height'
    model = LinearRegression() 
    X_train = df_filtered[x_values]
    Y_train = df_filtered[y_values]
    model.fit(X_train, Y_train)
    return {
        "coef": model.coef_.tolist(),
        "intercept": float(model.intercept_),
        "count": len(df_filtered),
    }

# %%
def count_func():
    import pandas as pd
    df = pd.read_csv("/app/data/worker-data.csv")
    return {"count": len(df)}

# %%
def mean_func():
    import pandas as pd
    df = pd.read_csv("/app/data/worker-data.csv")
    count =  len(df)
    mean = df['age'].mean()
    return {"count": count, "mean":mean}

# %%
def variance_func():
    import pandas as pd
    df = pd.read_csv("/app/data/worker-data.csv")
    count =  len(df)
    mean = df['age'].mean()
    variance = df['age'].var()
    return {"count": count, "mean":mean,"variance":variance }

# %%
#Single data node

# %%
result = nectar_client.byoc_query(
    count_func, 
    bucket_ids=[bucket_ids[16]],
    operation="count",
    policy_indexes=[0],
    use_allowlists=[True],
    access_indexes=[0]
)
# Out:
# Checking the current logged-in user's role.
# Sending query to blockchain...
# approving query payment...
# encrypting query under star node key...
# Encryption completed using the public key
# sending query with payment...
# waiting for mpc result...
# query number: 302
# decrypting result...
# done
# result:
# --------------------------------------------------
# b'69'
# --------------------------------------------------

# %%
result
# Out:
# 302

# %%
print(nectar_client.get_result(result))
# Out:
# query number: 302
# decrypting result...
# done
# result:
# --------------------------------------------------
# b'69'
# --------------------------------------------------
# 302

# %%
### Multiple data node

# %%
result = nectar_client.byoc_query(
    linear_regression_func, 
    bucket_ids=[bucket_ids[0], bucket_ids[1]],
    operation="linear-regression",
    policy_indexes=[0, 0],
    use_allowlists=[True, True],
    access_indexes=[0, 0]
)

# %%
print(result)

# %%
result = nectar_client.byoc_query(
    count_func, 
    bucket_ids=[bucket_ids[0], bucket_ids[1]],
    operation="count",
    policy_indexes=[0, 0]
    use_allowlists=[True, True],
    access_indexes=[0, 0]
)

# %%
print(result)

# %%
result = nectar_client.byoc_query(
    mean_func, 
    bucket_ids=[bucket_ids[0], bucket_ids[1]],
    operation="mean",
    policy_indexes=[0, 0],
    use_allowlists=[True, True],
    access_indexes=[0, 0]
)

# %%
print(result)

# %%
result = nectar_client.byoc_query(
    variance_func, 
    bucket_ids=[bucket_ids[0], bucket_ids[1]],
    operation="variance",
    policy_indexes=[0, 0],
    use_allowlists=[True, True],
    access_indexes=[0, 0]
)

# %%
print(result)
